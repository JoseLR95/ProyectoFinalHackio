# %%
import pandas as pd
pd.set_option('display.max_columns', None)

# %%
df_jugadores = pd.read_csv("data/jugadores_info_normalizado.csv")

# %%
df_jugadores.columns
# Out:
# Index(['playerID', 'playerImage', 'playerName', 'playerFullName', 'birthplace',
#        'dateOfBirth', 'dateOfDeath', 'playerShirtNumber', 'birthplaceCountry',
#        'birthplaceCountryImage', 'age', 'height', 'foot', 'internationalTeam',
#        'internationalTeamImage', 'internationalTeamStatus',
#        'internationalGames', 'internationalGoals', 'internationalTeamShortTag',
#        'internationalShirtNumber', 'internationalWmMember',
#        'internationalValueRank', 'country', 'countrynameEN', 'countryImage',
#        'countryShortName', 'secondCountry', 'secondCountryImage', 'league',
#        'leaguenameEN', 'leagueLogo', 'clubImage', 'club', 'clubnameEN',
#        'clubID', 'loan', 'contractExpiryDate', 'agent', 'agentId',
#        'agentVerificationStatus', 'agentVerificationDate', 'outfitter',
#        'positionGroup', 'playerMainPosition', 'playerSecondPosition',
#        'playerThirdPosition', 'marketValue', 'marketValueCurrency',
#        'marketValueNumeral', 'marketValueLastChange', 'relatedness', 'injury',
#        'absence', 'allSuspensions'],
#       dtype='object')

# %%
df_jugadores_columnasok = df_jugadores[['playerID', 'playerName', 'playerFullName', 'birthplace',
       'dateOfBirth', 'birthplaceCountry', 'age', 'height', 'foot', 'internationalTeam',
       'internationalGames', 'internationalGoals', 'country', 'secondCountry', 'club',
       'clubID', 'playerMainPosition', 'playerSecondPosition',
       'playerThirdPosition']]

# %%
df_jugadores_columnasok.rename(columns = {
    'playerName': 'Nombre_Jugador',
    'playerFullName': 'Nombre_Completo_Jugador',
    'birthplace': 'Lugar_Nacimiento',
    'dateOfBirth': 'Fecha_Nacimiento',
    'birthplaceCountry': 'Pais_Nacimiento',
    'age': 'Edad',
    'height': 'Altura',
    'foot': 'Pie_Dominante',
    'internationalTeam': 'Equipo_Internacional',
    'internationalGames': 'Partidos_Internacionales',
    'internationalGoals': 'Goles_Internacionales',
    'country': 'Pais',
    'secondCountry': 'Segundo_Pais',
    'club': 'Club',
    'playerMainPosition': 'Posicion_Principal',
    'playerSecondPosition': 'Posicion_Secundaria',
    'playerThirdPosition': 'Posicion_Terciaria'
}, inplace = True)
# Out:
# C:\Users\pepel\AppData\Local\Temp\ipykernel_56168\3125397185.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_jugadores_columnasok.rename(columns = {

# %%
df_jugadores_columnasok
# Out:
#      playerID    Nombre_Jugador       Nombre_Completo_Jugador  \
# 0     10609.0    Jérémy Mathieu                Jérémy Mathieu
# 1      5216.0    Andrés Iniesta          Andrés Iniesta Luján
# 2      6332.0  Thomas Vermaelen              Thomas Vermaelen
# 3      4324.0        Dani Alves         Daniel Alves da Silva
# 4      5213.0      Gerard Piqué         Gerard Piqué Bernabéu
# ..        ...               ...                           ...
# 623       NaN     Álvaro Traver                 Álvaro Traver
# 624    5678.0   Jefferson Lerma  Jefferson Andrés Lerma Solís
# 625    6659.0   Víctor Camarasa      Víctor Camarasa Ferrando
# 626       NaN        Dani Calvo                    Dani Calvo
# 627       NaN            Pepelu         José Luis García Vayá
#
#       Lugar_Nacimiento Fecha_Nacimiento Pais_Nacimiento  Edad Altura  \
# 0    Luxeuil-les-Bains       29/10/1983         Francia    41   1,89
# 1        Fuentealbilla       11/05/1984          España    40   1,71
# 2             Kapellen       14/11/1985         Bélgica    39   1,83
# 3             Juazeiro       06/05/1983          Brasil    41   1,72
# 4            Barcelona       02/02/1987          España    38   1,94
# ..                 ...              ...             ...   ...    ...
# 623           Algemesí       01/04/1993          España    32   1,87
# 624            Cerrito       25/10/1994        Colombia    30   1,79
# 625            Meliana       28/05/1994          España    30   1,83
# 626             Huesca       01/04/1994          España    31   1,93
# 627              Dénia       11/08/1998          España    26   1,86
#
#     Pie_Dominante Equipo_Internacional  Partidos_Internacionales  \
# 0       Izquierdo              Francia                       5.0
# 1     Ambidiestro               España                     131.0
# 2       Izquierdo              Bélgica                      85.0
# 3         Derecho               Brasil                     126.0
# 4         Derecho               España                     102.0
# ..            ...                  ...                       ...
# 623       Derecho                  NaN                       NaN
# 624       Derecho             Colombia                      54.0
# 625       Derecho        España Sub-21                       4.0
# 626       Derecho                  NaN                       NaN
# 627       Derecho               España                       0.0
#
#      Goles_Internacionales      Pais Segundo_Pais        Club  clubID  \
# 0                      0.0   Francia          NaN   Barcelona   217.0
# 1                     14.0    España          NaN   Barcelona   217.0
# 2                      2.0   Bélgica          NaN   Barcelona   217.0
# 3                      8.0    Brasil       España   Barcelona   217.0
# 4                      5.0    España          NaN   Barcelona   217.0
# ..                     ...       ...          ...         ...     ...
# 623                    NaN    España          NaN         NaN     NaN
# 624                    3.0  Colombia          NaN  Levante UD   221.0
# 625                    0.0    España          NaN  Levante UD   221.0
# 626                    NaN    España          NaN         NaN     NaN
# 627                    0.0    España          NaN         NaN     NaN
#
#     Posicion_Principal   Posicion_Secundaria  Posicion_Terciaria
# 0    Lateral izquierdo       Defensa central  Interior izquierdo
# 1          Mediocentro  Mediocentro ofensivo                 NaN
# 2      Defensa central     Lateral izquierdo                 NaN
# 3      Lateral derecho      Interior derecho         Mediocentro
# 4      Defensa central                   NaN                 NaN
# ..                 ...                   ...                 ...
# 623    Extremo derecho     Extremo izquierdo                 NaN
# 624             Pivote           Mediocentro                 NaN
# 625        Mediocentro  Mediocentro ofensivo                 NaN
# 626    Defensa central                   NaN                 NaN
# 627             Pivote           Mediocentro                 NaN
#
# [628 rows x 19 columns]
